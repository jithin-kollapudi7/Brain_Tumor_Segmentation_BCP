# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a Series
data = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])
print(data)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
# Create a DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df = pd.read_csv("example.csv")  
print(df.head())  # Display the first 5 rows
# Out:
#       Name   Age      City
# 0  Charlie  47.0  San Jose
# 1    Diana  43.0  New York
# 2   Hannah  21.0   Chicago
# 3      NaN  43.0   Houston
# 4    Fiona  40.0   Houston

# %%
import os
print(os.getcwd())
# Out:
# /Users/jithinkollapudi/Desktop/Brain_Tumor_Segmentation_BCP/Week_1/Python_libraries/Pandas

# %%
df.to_csv("output.csv", index=False)

# %%
# Access a column
print(df["Name"])

# Access a row by index
print(df.iloc[1])  # Second row

# Access a row by label
print(df.loc[0])  # First row
# Out:
# 0     Charlie
# 1       Diana
# 2      Hannah
# 3         NaN
# 4       Fiona
# 5      Edward
# 6         NaN
# 7         Ivy
# 8        Jack
# 9      Edward
# 10        Bob
# 11     George
# Name: Name, dtype: object
# Name       Diana
# Age         43.0
# City    New York
# Name: 1, dtype: object
# Name     Charlie
# Age         47.0
# City    San Jose
# Name: 0, dtype: object

# %%
# Filter rows where Age > 25
filtered_df = df[df["Age"] > 25]
print(filtered_df)
# Out:
#       Name   Age         City
# 0  Charlie  47.0     San Jose
# 1    Diana  43.0     New York
# 3      NaN  43.0      Houston
# 4    Fiona  40.0      Houston
# 6      NaN  38.0  Los Angeles

# %%
# Add a new column
df["Salary"] = [50000, 60000, 70000, 55000, 65000, 75000, 52000, 62000, 72000, 58000, 68000, 78000]

# %%
print(df.describe())  # Summary statistics
print(df.info())      # DataFrame information
# Out:
#              Age        Salary
# count  10.000000     12.000000
# mean   32.200000  63750.000000
# std    10.942273   9096.702699
# min    18.000000  50000.000000
# 25%    23.250000  57250.000000
# 50%    31.500000  63500.000000
# 75%    42.250000  70500.000000
# max    47.000000  78000.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     float64
#  2   City    12 non-null     object
#  3   Salary  12 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 516.0+ bytes
# None

# %%
# Sort by Age
df_sorted = df.sort_values(by="Age", ascending=False)
print(df_sorted)
# Out:
#        Name   Age         City  Salary
# 0   Charlie  47.0     San Jose   50000
# 1     Diana  43.0     New York   60000
# 3       NaN  43.0      Houston   55000
# 4     Fiona  40.0      Houston   65000
# 6       NaN  38.0  Los Angeles   52000
# 8      Jack  25.0     New York   72000
# 11   George  24.0      Chicago   78000
# 7       Ivy  23.0     New York   62000
# 2    Hannah  21.0      Chicago   70000
# 9    Edward  18.0       Dallas   58000
# 5    Edward   NaN       Dallas   75000
# 10      Bob   NaN  Los Angeles   68000

# %%
# Group by a column and calculate the mean
grouped = df.groupby("City")["Age"].mean()
print(grouped)
# Out:
# City
# Chicago        22.500000
# Dallas         18.000000
# Houston        41.500000
# Los Angeles    38.000000
# New York       30.333333
# San Jose       47.000000
# Name: Age, dtype: float64

# %%
# Fill missing values
df["Age"] = df["Age"].fillna(df["Age"].mean())
print(df)
print("")

# Drop a column
df = df.drop(columns=["City"])
print(df)
print("")

# Drop rows with missing values
df = df.dropna()
print(df)
# Out:
#        Name   Age         City  Salary
# 0   Charlie  47.0     San Jose   50000
# 1     Diana  43.0     New York   60000
# 2    Hannah  21.0      Chicago   70000
# 3       NaN  43.0      Houston   55000
# 4     Fiona  40.0      Houston   65000
# 5    Edward  32.2       Dallas   75000
# 6       NaN  38.0  Los Angeles   52000
# 7       Ivy  23.0     New York   62000
# 8      Jack  25.0     New York   72000
# 9    Edward  18.0       Dallas   58000
# 10      Bob  32.2  Los Angeles   68000
# 11   George  24.0      Chicago   78000
#
#        Name   Age  Salary
# 0   Charlie  47.0   50000
# 1     Diana  43.0   60000
# 2    Hannah  21.0   70000
# 3       NaN  43.0   55000
# 4     Fiona  40.0   65000
# 5    Edward  32.2   75000
# 6       NaN  38.0   52000
# 7       Ivy  23.0   62000
# 8      Jack  25.0   72000
# 9    Edward  18.0   58000
# 10      Bob  32.2   68000
# 11   George  24.0   78000
#
#        Name   Age  Salary
# 0   Charlie  47.0   50000
# 1     Diana  43.0   60000
# 2    Hannah  21.0   70000
# 4     Fiona  40.0   65000
# 5    Edward  32.2   75000
# 7       Ivy  23.0   62000
# 8      Jack  25.0   72000
# 9    Edward  18.0   58000
# 10      Bob  32.2   68000
# 11   George  24.0   78000

# %%
df1 = pd.DataFrame({"A": [1, 2], "B": [3, 4]})
df2 = pd.DataFrame({"A": [5, 6], "B": [7, 8]})
result = pd.concat([df1, df2])
print(result)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 0  5  7
# 1  6  8

# %%
df1 = pd.DataFrame({"ID": [1, 2], "Name": ["Alice", "Bob"]})
df2 = pd.DataFrame({"ID": [1, 2], "Age": [25, 30]})
merged = pd.merge(df1, df2, on="ID")
print(merged)
# Out:
#    ID   Name  Age
# 0   1  Alice   25
# 1   2    Bob   30

# %%
# Plot data
df["Age"].plot(kind="bar", title="Age Distribution", color="skyblue")
plt.show()

# %% [markdown]
# ### Some assignment problems

# %%
# Assignment 1
'''
Import videogamesales.csv and perform the following actions on it
Add a column of 'global_sales' showing the total sales of all the different regions to the data frame and sort (highest first) and print the DataFrame according to it.
Display a plot of the total number of copies sold of each genre globally.
Filter out only the games containing 'Grand Theft Auto' in their name and display the following as a DataFrame:
a. their name
b. the platform they were released on
c. the year they were released in
d. the sum of sales in only Europe and Japan
Display a pie chart of the total sales of all Grand Theft Auto games combined in North America, Europe, Japan, and other sales.
'''
# Out:
# "\nImport videogamesales.csv and perform the following actions on it\nAdd a column of 'global_sales' showing the total sales of all the different regions to the data frame and sort (highest first) and print the DataFrame according to it.\nDisplay a plot of the total number of copies sold of each genre globally.\nFilter out only the games containing 'Grand Theft Auto' in their name and display the following as a DataFrame:\na. their name\nb. the platform they were released on\nc. the year they were released in\nd. the sum of sales in only Europe and Japan\nDisplay a pie chart of the total sales of all Grand Theft Auto games combined in North America, Europe, Japan, and other sales.\n"

# %%
df = pd.read_csv("videogamesales.csv")
df["global_sales"] = df["NA_Sales"]+df["EU_Sales"]+df["JP_Sales"]+df["Other_Sales"]
df_sorted = df.sort_values(by="global_sales",ascending=False)
print(df_sorted)
# Out:
#                                                    Name Platform    Year  \
# 6109                                         Wii Sports      Wii  2006.0
# 122                                   Super Mario Bros.      NES  1985.0
# 8315                                     Mario Kart Wii      Wii  2008.0
# 9743                                  Wii Sports Resort      Wii  2009.0
# 705                            Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 10978       Military History: Commander - Europe at War       DS  2009.0
# 7971            Puzzle Quest: Challenge of the Warlords      PSP  2007.0
# 7972                         Race Driver: Create & Race       DS  2007.0
# 10854                                   Cross Edge Dash     X360  2009.0
# 9650   SCORE International Baja 1000: The Official Game      PS2  2008.0
#
#               Genre            Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 6109         Sports             Nintendo     41.49     29.02      3.77
# 122        Platform             Nintendo     29.08      3.58      6.81
# 8315         Racing             Nintendo     15.85     12.88      3.79
# 9743         Sports             Nintendo     15.75     11.01      3.28
# 705    Role-Playing             Nintendo     11.27      8.89     10.22
# ...             ...                  ...       ...       ...       ...
# 10978      Strategy  Slitherine Software      0.00      0.01      0.00
# 7971         Puzzle          D3Publisher      0.01      0.00      0.00
# 7972         Racing          Codemasters      0.01      0.00      0.00
# 10854  Role-Playing        Compile Heart      0.00      0.00      0.01
# 9650         Racing           Activision      0.00      0.00      0.00
#
#        Other_Sales  global_sales
# 6109          8.46         82.74
# 122           0.77         40.24
# 8315          3.31         35.83
# 9743          2.96         33.00
# 705           1.00         31.38
# ...            ...           ...
# 10978         0.00          0.01
# 7971          0.00          0.01
# 7972          0.00          0.01
# 10854         0.00          0.01
# 9650          0.00          0.00
#
# [16583 rows x 10 columns]

# %%
genre_sales = df.groupby("Genre")["global_sales"].sum()
genre_sales.plot(kind="bar")
plt.xlabel("Genre")
plt.ylabel("Total Copies Sold (Global)")
plt.title("Total Global Video Game Sales by Genre")
plt.show()

# %%
gta_games = df[df["Name"].str.contains("Grand Theft Auto", case=False, na=False)]
gta_names = gta_games[["Name"]]
print(gta_names)
# Out:
#                                                     Name
# 999                                     Grand Theft Auto
# 1290                                  Grand Theft Auto 2
# 1469      Grand Theft Auto: Mission Pack #1, London 1969
# 2323                                Grand Theft Auto III
# 2805                         Grand Theft Auto: Vice City
# 3563                                Grand Theft Auto III
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...
# 4356                         Grand Theft Auto: Vice City
# 4405                       Grand Theft Auto: San Andreas
# 4704                                    Grand Theft Auto
# 5173              Grand Theft Auto: Liberty City Stories
# 5197                       Grand Theft Auto: San Andreas
# 6041                       Grand Theft Auto: San Andreas
# 6125                 Grand Theft Auto: Vice City Stories  2006.0
# 6128              Grand Theft Auto: Liberty City Stories  2006.0
# 7199                 Grand Theft Auto: Vice City Stories  2007.0
# 8316                                 Grand Theft Auto IV  2008.0
# 8319                                 Grand Theft Auto IV  2008.0
# 9072                       Grand Theft Auto: San Andreas  2008.0
# 9379                                 Grand Theft Auto IV  2008.0
# 9848                    Grand Theft Auto: Chinatown Wars  2009.0
# 10007                   Grand Theft Auto: Chinatown Wars  2009.0
# 14222                                 Grand Theft Auto V  2013.0
# 14223                                 Grand Theft Auto V  2013.0
# 14769                                 Grand Theft Auto V  2014.0
# 14775                                 Grand Theft Auto V  2014.0
# 15421                                 Grand Theft Auto V  2015.0

# %%
gta_games = df[df["Name"].str.contains("Grand Theft Auto", case=False)].copy()
gta_games["EU_JP_Sales"] = gta_games["EU_Sales"] + gta_games["JP_Sales"]
gta_sales = gta_games[["Name", "EU_JP_Sales"]]
print(gta_sales)
# Out:
#                                                     Name  EU_JP_Sales
# 999                                     Grand Theft Auto         1.39
# 1290                                  Grand Theft Auto 2         2.07
# 1469      Grand Theft Auto: Mission Pack #1, London 1969         0.04
# 2323                                Grand Theft Auto III         4.81
# 2805                         Grand Theft Auto: Vice City         5.96
# 3563                                Grand Theft Auto III         0.01
# 3639   Rockstar Games Double Pack: Grand Theft Auto I...         0.56
# 3688   Rockstar Games Double Pack: Grand Theft Auto I...         0.66
# 4356                         Grand Theft Auto: Vice City         0.03
# 4405                       Grand Theft Auto: San Andreas         0.81
# 4704                                    Grand Theft Auto         0.06
# 5173              Grand Theft Auto: Liberty City Stories         3.07
# 5197                       Grand Theft Auto: San Andreas         0.61
# 6041                       Grand Theft Auto: San Andreas         0.92
# 6125                 Grand Theft Auto: Vice City Stories         2.18
# 6128              Grand Theft Auto: Liberty City Stories         1.47
# 7199                 Grand Theft Auto: Vice City Stories         0.06
# 8316                                 Grand Theft Auto IV         3.24
# 8319                                 Grand Theft Auto IV         4.20
# 9072                       Grand Theft Auto: San Andreas         0.03
# 9379                                 Grand Theft Auto IV         0.79
# 9848                    Grand Theft Auto: Chinatown Wars         0.62
# 10007                   Grand Theft Auto: Chinatown Wars         0.53
# 14222                                 Grand Theft Auto V         5.37
# 14223                                 Grand Theft Auto V        10.24
# 14769                                 Grand Theft Auto V         6.17
# 14775                                 Grand Theft Auto V         2.01
# 15421                                 Grand Theft Auto V         0.64

# %%
gta_games = df[df["Name"].str.contains("Grand Theft Auto", case=False, na=False)]
na_total = gta_games["NA_Sales"].sum()
eu_total = gta_games["EU_Sales"].sum()
jp_total = gta_games["JP_Sales"].sum()
other_total = gta_games["Other_Sales"].sum()
sales = [na_total, eu_total, jp_total, other_total]
labels = ["North America", "Europe", "Japan", "Other"]
plt.pie(sales, labels=labels, autopct="%1.1f%%", startangle=140)
plt.title("Distribution of Total GTA Sales by Region")
plt.show()
